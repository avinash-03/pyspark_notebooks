# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import year, month, dayofmonth

# %%
spark = SparkSession.builder.appName('github notebook').master("local").getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://avinash:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>github notebook</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df = spark.read.format("json").load("../ghfile/*.json.gz")

# %%
df.printSchema()
# Out:
# root
#  |-- actor: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- display_login: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- org: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- payload: struct (nullable = true)
#  |    |-- action: string (nullable = true)
#  |    |-- before: string (nullable = true)
#  |    |-- comment: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- commit_id: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- diff_hunk: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- in_reply_to_id: long (nullable = true)
#  |    |    |-- issue_url: string (nullable = true)
#  |    |    |-- line: long (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- original_commit_id: string (nullable = true)
#  |    |    |-- original_line: long (nullable = true)
#  |    |    |-- original_position: long (nullable = true)
#  |    |    |-- original_start_line: long (nullable = true)
#  |    |    |-- path: string (nullable = true)
#  |    |    |-- performed_via_github_app: struct (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- events: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- external_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- permissions: struct (nullable = true)
#  |    |    |    |    |-- checks: string (nullable = true)
#  |    |    |    |    |-- contents: string (nullable = true)
#  |    |    |    |    |-- emails: string (nullable = true)
#  |    |    |    |    |-- issues: string (nullable = true)
#  |    |    |    |    |-- members: string (nullable = true)
#  |    |    |    |    |-- metadata: string (nullable = true)
#  |    |    |    |    |-- organization_administration: string (nullable = true)
#  |    |    |    |    |-- pull_requests: string (nullable = true)
#  |    |    |    |    |-- repository_hooks: string (nullable = true)
#  |    |    |    |    |-- statuses: string (nullable = true)
#  |    |    |    |-- slug: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- position: long (nullable = true)
#  |    |    |-- pull_request_review_id: long (nullable = true)
#  |    |    |-- pull_request_url: string (nullable = true)
#  |    |    |-- reactions: struct (nullable = true)
#  |    |    |    |-- +1: long (nullable = true)
#  |    |    |    |-- -1: long (nullable = true)
#  |    |    |    |-- confused: long (nullable = true)
#  |    |    |    |-- eyes: long (nullable = true)
#  |    |    |    |-- heart: long (nullable = true)
#  |    |    |    |-- hooray: long (nullable = true)
#  |    |    |    |-- laugh: long (nullable = true)
#  |    |    |    |-- rocket: long (nullable = true)
#  |    |    |    |-- total_count: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- side: string (nullable = true)
#  |    |    |-- start_line: long (nullable = true)
#  |    |    |-- start_side: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- commits: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- author: struct (nullable = true)
#  |    |    |    |    |-- email: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- distinct: boolean (nullable = true)
#  |    |    |    |-- message: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- distinct_size: long (nullable = true)
#  |    |-- forkee: struct (nullable = true)
#  |    |    |-- allow_forking: boolean (nullable = true)
#  |    |    |-- archive_url: string (nullable = true)
#  |    |    |-- archived: boolean (nullable = true)
#  |    |    |-- assignees_url: string (nullable = true)
#  |    |    |-- blobs_url: string (nullable = true)
#  |    |    |-- branches_url: string (nullable = true)
#  |    |    |-- clone_url: string (nullable = true)
#  |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- compare_url: string (nullable = true)
#  |    |    |-- contents_url: string (nullable = true)
#  |    |    |-- contributors_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_branch: string (nullable = true)
#  |    |    |-- deployments_url: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- disabled: boolean (nullable = true)
#  |    |    |-- downloads_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- fork: boolean (nullable = true)
#  |    |    |-- forks: long (nullable = true)
#  |    |    |-- forks_count: long (nullable = true)
#  |    |    |-- forks_url: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |-- git_url: string (nullable = true)
#  |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |-- homepage: string (nullable = true)
#  |    |    |-- hooks_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- is_template: boolean (nullable = true)
#  |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |-- issues_url: string (nullable = true)
#  |    |    |-- keys_url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- language: string (nullable = true)
#  |    |    |-- languages_url: string (nullable = true)
#  |    |    |-- license: struct (nullable = true)
#  |    |    |    |-- key: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- merges_url: string (nullable = true)
#  |    |    |-- milestones_url: string (nullable = true)
#  |    |    |-- mirror_url: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- notifications_url: string (nullable = true)
#  |    |    |-- open_issues: long (nullable = true)
#  |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |-- owner: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- private: boolean (nullable = true)
#  |    |    |-- public: boolean (nullable = true)
#  |    |    |-- pulls_url: string (nullable = true)
#  |    |    |-- pushed_at: string (nullable = true)
#  |    |    |-- releases_url: string (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- ssh_url: string (nullable = true)
#  |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |-- subscription_url: string (nullable = true)
#  |    |    |-- svn_url: string (nullable = true)
#  |    |    |-- tags_url: string (nullable = true)
#  |    |    |-- teams_url: string (nullable = true)
#  |    |    |-- topics: array (nullable = true)
#  |    |    |    |-- element: string (containsNull = true)
#  |    |    |-- trees_url: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- visibility: string (nullable = true)
#  |    |    |-- watchers: long (nullable = true)
#  |    |    |-- watchers_count: long (nullable = true)
#  |    |    |-- web_commit_signoff_required: boolean (nullable = true)
#  |    |-- head: string (nullable = true)
#  |    |-- issue: struct (nullable = true)
#  |    |    |-- active_lock_reason: string (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assignees: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- labels: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |-- default: boolean (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- locked: boolean (nullable = true)
#  |    |    |-- milestone: struct (nullable = true)
#  |    |    |    |-- closed_at: string (nullable = true)
#  |    |    |    |-- closed_issues: long (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- creator: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- performed_via_github_app: struct (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- events: array (nullable = true)
#  |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |-- external_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- permissions: struct (nullable = true)
#  |    |    |    |    |-- contents: string (nullable = true)
#  |    |    |    |    |-- discussions: string (nullable = true)
#  |    |    |    |    |-- issues: string (nullable = true)
#  |    |    |    |    |-- metadata: string (nullable = true)
#  |    |    |    |    |-- statuses: string (nullable = true)
#  |    |    |    |-- slug: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |-- diff_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- merged_at: string (nullable = true)
#  |    |    |    |-- patch_url: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- reactions: struct (nullable = true)
#  |    |    |    |-- +1: long (nullable = true)
#  |    |    |    |-- -1: long (nullable = true)
#  |    |    |    |-- confused: long (nullable = true)
#  |    |    |    |-- eyes: long (nullable = true)
#  |    |    |    |-- heart: long (nullable = true)
#  |    |    |    |-- hooray: long (nullable = true)
#  |    |    |    |-- laugh: long (nullable = true)
#  |    |    |    |-- rocket: long (nullable = true)
#  |    |    |    |-- total_count: long (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- repository_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- state_reason: string (nullable = true)
#  |    |    |-- timeline_url: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- master_branch: string (nullable = true)
#  |    |-- member: struct (nullable = true)
#  |    |    |-- avatar_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- followers_url: string (nullable = true)
#  |    |    |-- following_url: string (nullable = true)
#  |    |    |-- gists_url: string (nullable = true)
#  |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- login: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- organizations_url: string (nullable = true)
#  |    |    |-- received_events_url: string (nullable = true)
#  |    |    |-- repos_url: string (nullable = true)
#  |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |-- starred_url: string (nullable = true)
#  |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- number: long (nullable = true)
#  |    |-- pages: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- action: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- page_name: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- summary: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |-- pull_request: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- commits: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- issue: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comment: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- statuses: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- active_lock_reason: string (nullable = true)
#  |    |    |-- additions: long (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assignees: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- auto_merge: struct (nullable = true)
#  |    |    |    |-- commit_message: string (nullable = true)
#  |    |    |    |-- commit_title: string (nullable = true)
#  |    |    |    |-- enabled_by: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- merge_method: string (nullable = true)
#  |    |    |-- base: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- allow_forking: boolean (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- archived: boolean (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- deployments_url: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- disabled: boolean (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- is_template: boolean (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
#  |    |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- private: boolean (nullable = true)
#  |    |    |    |    |-- pulls_url: string (nullable = true)
#  |    |    |    |    |-- pushed_at: string (nullable = true)
#  |    |    |    |    |-- releases_url: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- ssh_url: string (nullable = true)
#  |    |    |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |    |    |-- statuses_url: string (nullable = true)
#  |    |    |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |    |    |-- subscription_url: string (nullable = true)
#  |    |    |    |    |-- svn_url: string (nullable = true)
#  |    |    |    |    |-- tags_url: string (nullable = true)
#  |    |    |    |    |-- teams_url: string (nullable = true)
#  |    |    |    |    |-- topics: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- trees_url: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- visibility: string (nullable = true)
#  |    |    |    |    |-- watchers: long (nullable = true)
#  |    |    |    |    |-- watchers_count: long (nullable = true)
#  |    |    |    |    |-- web_commit_signoff_required: boolean (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- user: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- changed_files: long (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits: long (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- deletions: long (nullable = true)
#  |    |    |-- diff_url: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- head: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- allow_forking: boolean (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- archived: boolean (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- deployments_url: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- disabled: boolean (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- is_template: boolean (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
#  |    |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- private: boolean (nullable = true)
#  |    |    |    |    |-- pulls_url: string (nullable = true)
#  |    |    |    |    |-- pushed_at: string (nullable = true)
#  |    |    |    |    |-- releases_url: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- ssh_url: string (nullable = true)
#  |    |    |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |    |    |-- statuses_url: string (nullable = true)
#  |    |    |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |    |    |-- subscription_url: string (nullable = true)
#  |    |    |    |    |-- svn_url: string (nullable = true)
#  |    |    |    |    |-- tags_url: string (nullable = true)
#  |    |    |    |    |-- teams_url: string (nullable = true)
#  |    |    |    |    |-- topics: array (nullable = true)
#  |    |    |    |    |    |-- element: string (containsNull = true)
#  |    |    |    |    |-- trees_url: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- visibility: string (nullable = true)
#  |    |    |    |    |-- watchers: long (nullable = true)
#  |    |    |    |    |-- watchers_count: long (nullable = true)
#  |    |    |    |    |-- web_commit_signoff_required: boolean (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- user: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- issue_url: string (nullable = true)
#  |    |    |-- labels: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |-- default: boolean (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- locked: boolean (nullable = true)
#  |    |    |-- maintainer_can_modify: boolean (nullable = true)
#  |    |    |-- merge_commit_sha: string (nullable = true)
#  |    |    |-- mergeable: boolean (nullable = true)
#  |    |    |-- mergeable_state: string (nullable = true)
#  |    |    |-- merged: boolean (nullable = true)
#  |    |    |-- merged_at: string (nullable = true)
#  |    |    |-- merged_by: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- milestone: struct (nullable = true)
#  |    |    |    |-- closed_at: string (nullable = true)
#  |    |    |    |-- closed_issues: long (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- creator: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- patch_url: string (nullable = true)
#  |    |    |-- rebaseable: boolean (nullable = true)
#  |    |    |-- requested_reviewers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- requested_teams: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- members_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- parent: string (nullable = true)
#  |    |    |    |    |-- permission: string (nullable = true)
#  |    |    |    |    |-- privacy: string (nullable = true)
#  |    |    |    |    |-- repositories_url: string (nullable = true)
#  |    |    |    |    |-- slug: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- review_comment_url: string (nullable = true)
#  |    |    |-- review_comments: long (nullable = true)
#  |    |    |-- review_comments_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- push_id: long (nullable = true)
#  |    |-- pusher_type: string (nullable = true)
#  |    |-- ref: string (nullable = true)
#  |    |-- ref_type: string (nullable = true)
#  |    |-- release: struct (nullable = true)
#  |    |    |-- assets: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- browser_download_url: string (nullable = true)
#  |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- download_count: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- uploader: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assets_url: string (nullable = true)
#  |    |    |-- author: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- discussion_url: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- is_short_description_html_truncated: boolean (nullable = true)
#  |    |    |-- mentions: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- avatar_user_actor: boolean (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- profile_name: string (nullable = true)
#  |    |    |    |    |-- profile_url: string (nullable = true)
#  |    |    |-- mentions_count: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- prerelease: boolean (nullable = true)
#  |    |    |-- published_at: string (nullable = true)
#  |    |    |-- short_description_html: string (nullable = true)
#  |    |    |-- tag_name: string (nullable = true)
#  |    |    |-- tarball_url: string (nullable = true)
#  |    |    |-- target_commitish: string (nullable = true)
#  |    |    |-- upload_url: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- zipball_url: string (nullable = true)
#  |    |-- review: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- commit_id: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- pull_request_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- submitted_at: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- size: long (nullable = true)
#  |-- public: boolean (nullable = true)
#  |-- repo: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- type: string (nullable = true)

# %%
df.columns
# Out:
# ['actor', 'created_at', 'id', 'org', 'payload', 'public', 'repo', 'type']

# %%
df.show()
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+------+--------------------+-----------------+
# |               actor|          created_at|        id|                 org|             payload|public|                repo|             type|
# +--------------------+--------------------+----------+--------------------+--------------------+------+--------------------+-----------------+
# |[https://avatars....|2018-07-24T16:00:00Z|8011174342|                null|[, 3d02b5ff979cea...|  true|[142025706, gameb...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174355|[https://avatars....|[created,, [, CON...|  true|[10941409, mesosp...|IssueCommentEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174362|                null|[, d8a47b6700dd02...|  true|[142157684, guiCa...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174365|                null|[, 325a4f61c4d8e8...|  true|[135834980, Rtcas...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174366|                null|[, 38a88744ae293c...|  true|[142036030, art12...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174368|[https://avatars....|[,,,, Angular (v2...|  true|[81668836, iotile...|      CreateEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174375|                null|[, 0de028a3f7946e...|  true|[86505380, davidp...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174376|                null|[,,,, Detta plugi...|  true|[142181923, PadsC...|      CreateEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174381|[https://avatars....|[started,,,,,,,,,...|  true|[64603480, EngFor...|       WatchEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174382|                null|[, 45742462b5549b...|  true|[142179091, seren...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174385|                null|[, 7ad58ffaed214d...|  true|[138676186, himob...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174386|                null|[, cd6a87f5694914...|  true|[142169764, shaly...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174393|[https://avatars....|[, f5d2399cd53202...|  true|[25623942, apache...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174397|                null|[, 6d550d9d6d3884...|  true|[135091897, Agata...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174406|                null|[,,,,,,,,, master...|  true|[139280926, benke...|      CreateEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174417|[https://avatars....|[closed,,,,,,,,,,...|  true|[8859285, wordpre...| PullRequestEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174420|                null|[, fa32ad6425f30d...|  true|[75402138, richar...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174422|[https://avatars....|[, 20f39530dc12e9...|  true|[126059498, Plaje...|        PushEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174423|                null|[published,,,,,,,...|  true|[142180375, JuAle...|     ReleaseEvent|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174428|[https://avatars....|[, d48bb8a452494f...|  true|[61103370, legato...|        PushEvent|
# +--------------------+--------------------+----------+--------------------+--------------------+------+--------------------+-----------------+
# only showing top 20 rows

# %%
df.select("repo.*").show()
# Out:
# +---------+--------------------+--------------------+
# |       id|                name|                 url|
# +---------+--------------------+--------------------+
# |142025706|gamebasedmarketin...|https://api.githu...|
# | 10941409| mesosphere/marathon|https://api.githu...|
# |142157684|     guiCarlier/akka|https://api.githu...|
# |135834980|        Rtcash/Mercy|https://api.githu...|
# |142036030|art123craft/learn...|https://api.githu...|
# | 81668836|iotile/ng-iotile-...|https://api.githu...|
# | 86505380|   davidpatrick/docs|https://api.githu...|
# |142181923|      PadsCraft/Sova|https://api.githu...|
# | 64603480|EngForDev/awesome...|https://api.githu...|
# |142179091|serendipidoussoph...|https://api.githu...|
# |138676186|      himobi/hotspot|https://api.githu...|
# |142169764|       shaly/config1|https://api.githu...|
# | 25623942|      apache/syncope|https://api.githu...|
# |135091897|AgataDziubala/Git...|https://api.githu...|
# |139280926|benkerns09/GolfPl...|https://api.githu...|
# |  8859285|wordpress-mobile/...|https://api.githu...|
# | 75402138|richardchien/none...|https://api.githu...|
# |126059498|Plajer-Lair/Build...|https://api.githu...|
# |142180375|JuAlexandre/React...|https://api.githu...|
# | 61103370|legatoproject/leg...|https://api.githu...|
# +---------+--------------------+--------------------+
# only showing top 20 rows

# %%
df.withColumn("year",year('created_at')).show()
# Out:
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+----+
# |               actor|          created_at|         id|                 org|             payload|public|                repo|             type|year|
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+----+
# |[https://avatars....|2022-09-26T05:00:00Z|24214570454|                null|[, f52f75fea97fd5...|  true|[395936674, Hacke...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570455|                null|[, a4d7fa423f387c...|  true|[539200849, ofaru...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570470|                null|[opened,,,,,,,, [...|  true|[277422872, pddem...|      IssuesEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570473|                null|[opened,,,,,,,, [...|  true|[541400904, vhc06...|      IssuesEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570479|                null|[,,,,,,,,, main,,...|  true|[541414542, direw...|      CreateEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570484|                null|[created,, [, OWN...|  true|[541412008, Lesli...|IssueCommentEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570486|                null|[, ac0bbb31e025bf...|  true|[536363176, hauch...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570492|                null|[closed,,,,,,,,,,...|  true|[533751899, MsWik...| PullRequestEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570497|                null|[,,,,,,,,, main,,...|  true|[541392028, sangh...|      CreateEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570498|                null|[,,,,,,,,, main,,...|  true|[541412270, JinYu...|      CreateEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570499|[https://avatars....|[, 208aa3904c3f92...|  true|[66585584, ingadh...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570502|[https://avatars....|[, 05c6d61026fc12...|  true|[520128187, guoba...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570505|[https://avatars....|[,,,,,,,,, main,,...|  true|[513771765, Husky...|      CreateEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570509|[https://avatars....|[,,,,,,,,,,,,,,, ...|  true|[513771765, Husky...|      DeleteEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570510|                null|[, 431624a101656c...|  true|[533751899, MsWik...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570528|                null|[closed,,,,,,,,,,...|  true|[435364435, dhire...| PullRequestEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570542|                null|[, 4235b4228fba6d...|  true|[534043114, Super...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570550|                null|[,,,,,,,,, main,,...|  true|[541414545, Vanpa...|      CreateEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570553|                null|[, 26681033d2556a...|  true|[541414048, Maria...|        PushEvent|2022|
# |[https://avatars....|2022-09-26T05:00:00Z|24214570558|                null|[, 2fbdf21cd37f37...|  true|[318202874, lixk2...|        PushEvent|2022|
# +--------------------+--------------------+-----------+--------------------+--------------------+------+--------------------+-----------------+----+
# only showing top 20 rows

# %%
df.count()
# Out:
# 644564

# %%
df1 = df.withColumn("year",year('created_at'))\
    .withColumn("month",month('created_at'))\
    .withColumn("day",dayofmonth('created_at'))

# %%
df1.write.partitionBy("year","month","day").parquet("output")

# %%
partitionBy

# %%
df3 = spark.read.parquet('output')

# %%
df3.printSchema()
# Out:
# root
#  |-- actor: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- display_login: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- created_at: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- org: struct (nullable = true)
#  |    |-- avatar_url: string (nullable = true)
#  |    |-- gravatar_id: string (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- login: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- payload: struct (nullable = true)
#  |    |-- action: string (nullable = true)
#  |    |-- before: string (nullable = true)
#  |    |-- comment: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- commit_id: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- diff_hunk: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- in_reply_to_id: long (nullable = true)
#  |    |    |-- issue_url: string (nullable = true)
#  |    |    |-- line: long (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- original_commit_id: string (nullable = true)
#  |    |    |-- original_position: long (nullable = true)
#  |    |    |-- path: string (nullable = true)
#  |    |    |-- position: long (nullable = true)
#  |    |    |-- pull_request_review_id: long (nullable = true)
#  |    |    |-- pull_request_url: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- commits: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- author: struct (nullable = true)
#  |    |    |    |    |-- email: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- distinct: boolean (nullable = true)
#  |    |    |    |-- message: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- description: string (nullable = true)
#  |    |-- distinct_size: long (nullable = true)
#  |    |-- forkee: struct (nullable = true)
#  |    |    |-- archive_url: string (nullable = true)
#  |    |    |-- archived: boolean (nullable = true)
#  |    |    |-- assignees_url: string (nullable = true)
#  |    |    |-- blobs_url: string (nullable = true)
#  |    |    |-- branches_url: string (nullable = true)
#  |    |    |-- clone_url: string (nullable = true)
#  |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- compare_url: string (nullable = true)
#  |    |    |-- contents_url: string (nullable = true)
#  |    |    |-- contributors_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- default_branch: string (nullable = true)
#  |    |    |-- deployments_url: string (nullable = true)
#  |    |    |-- description: string (nullable = true)
#  |    |    |-- downloads_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- fork: boolean (nullable = true)
#  |    |    |-- forks: long (nullable = true)
#  |    |    |-- forks_count: long (nullable = true)
#  |    |    |-- forks_url: string (nullable = true)
#  |    |    |-- full_name: string (nullable = true)
#  |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |-- git_url: string (nullable = true)
#  |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |-- homepage: string (nullable = true)
#  |    |    |-- hooks_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |-- issues_url: string (nullable = true)
#  |    |    |-- keys_url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- language: string (nullable = true)
#  |    |    |-- languages_url: string (nullable = true)
#  |    |    |-- license: struct (nullable = true)
#  |    |    |    |-- key: string (nullable = true)
#  |    |    |    |-- name: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- merges_url: string (nullable = true)
#  |    |    |-- milestones_url: string (nullable = true)
#  |    |    |-- mirror_url: string (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- notifications_url: string (nullable = true)
#  |    |    |-- open_issues: long (nullable = true)
#  |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |-- owner: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- private: boolean (nullable = true)
#  |    |    |-- public: boolean (nullable = true)
#  |    |    |-- pulls_url: string (nullable = true)
#  |    |    |-- pushed_at: string (nullable = true)
#  |    |    |-- releases_url: string (nullable = true)
#  |    |    |-- size: long (nullable = true)
#  |    |    |-- ssh_url: string (nullable = true)
#  |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |-- subscription_url: string (nullable = true)
#  |    |    |-- svn_url: string (nullable = true)
#  |    |    |-- tags_url: string (nullable = true)
#  |    |    |-- teams_url: string (nullable = true)
#  |    |    |-- trees_url: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- watchers: long (nullable = true)
#  |    |    |-- watchers_count: long (nullable = true)
#  |    |-- head: string (nullable = true)
#  |    |-- issue: struct (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assignees: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- labels: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |-- default: boolean (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- labels_url: string (nullable = true)
#  |    |    |-- locked: boolean (nullable = true)
#  |    |    |-- milestone: struct (nullable = true)
#  |    |    |    |-- closed_at: string (nullable = true)
#  |    |    |    |-- closed_issues: long (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- creator: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- pull_request: struct (nullable = true)
#  |    |    |    |-- diff_url: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- patch_url: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- repository_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- master_branch: string (nullable = true)
#  |    |-- member: struct (nullable = true)
#  |    |    |-- avatar_url: string (nullable = true)
#  |    |    |-- events_url: string (nullable = true)
#  |    |    |-- followers_url: string (nullable = true)
#  |    |    |-- following_url: string (nullable = true)
#  |    |    |-- gists_url: string (nullable = true)
#  |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- login: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- organizations_url: string (nullable = true)
#  |    |    |-- received_events_url: string (nullable = true)
#  |    |    |-- repos_url: string (nullable = true)
#  |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |-- starred_url: string (nullable = true)
#  |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |-- type: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |-- number: long (nullable = true)
#  |    |-- pages: array (nullable = true)
#  |    |    |-- element: struct (containsNull = true)
#  |    |    |    |-- action: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- page_name: string (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- summary: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |-- pull_request: struct (nullable = true)
#  |    |    |-- _links: struct (nullable = true)
#  |    |    |    |-- comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- commits: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- html: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- issue: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comment: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- review_comments: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- self: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |    |-- statuses: struct (nullable = true)
#  |    |    |    |    |-- href: string (nullable = true)
#  |    |    |-- additions: long (nullable = true)
#  |    |    |-- assignee: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assignees: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- author_association: string (nullable = true)
#  |    |    |-- base: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- archived: boolean (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- deployments_url: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
#  |    |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- private: boolean (nullable = true)
#  |    |    |    |    |-- pulls_url: string (nullable = true)
#  |    |    |    |    |-- pushed_at: string (nullable = true)
#  |    |    |    |    |-- releases_url: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- ssh_url: string (nullable = true)
#  |    |    |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |    |    |-- statuses_url: string (nullable = true)
#  |    |    |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |    |    |-- subscription_url: string (nullable = true)
#  |    |    |    |    |-- svn_url: string (nullable = true)
#  |    |    |    |    |-- tags_url: string (nullable = true)
#  |    |    |    |    |-- teams_url: string (nullable = true)
#  |    |    |    |    |-- trees_url: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- watchers: long (nullable = true)
#  |    |    |    |    |-- watchers_count: long (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- user: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- changed_files: long (nullable = true)
#  |    |    |-- closed_at: string (nullable = true)
#  |    |    |-- comments: long (nullable = true)
#  |    |    |-- comments_url: string (nullable = true)
#  |    |    |-- commits: long (nullable = true)
#  |    |    |-- commits_url: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- deletions: long (nullable = true)
#  |    |    |-- diff_url: string (nullable = true)
#  |    |    |-- head: struct (nullable = true)
#  |    |    |    |-- label: string (nullable = true)
#  |    |    |    |-- ref: string (nullable = true)
#  |    |    |    |-- repo: struct (nullable = true)
#  |    |    |    |    |-- archive_url: string (nullable = true)
#  |    |    |    |    |-- archived: boolean (nullable = true)
#  |    |    |    |    |-- assignees_url: string (nullable = true)
#  |    |    |    |    |-- blobs_url: string (nullable = true)
#  |    |    |    |    |-- branches_url: string (nullable = true)
#  |    |    |    |    |-- clone_url: string (nullable = true)
#  |    |    |    |    |-- collaborators_url: string (nullable = true)
#  |    |    |    |    |-- comments_url: string (nullable = true)
#  |    |    |    |    |-- commits_url: string (nullable = true)
#  |    |    |    |    |-- compare_url: string (nullable = true)
#  |    |    |    |    |-- contents_url: string (nullable = true)
#  |    |    |    |    |-- contributors_url: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- default_branch: string (nullable = true)
#  |    |    |    |    |-- deployments_url: string (nullable = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- downloads_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- fork: boolean (nullable = true)
#  |    |    |    |    |-- forks: long (nullable = true)
#  |    |    |    |    |-- forks_count: long (nullable = true)
#  |    |    |    |    |-- forks_url: string (nullable = true)
#  |    |    |    |    |-- full_name: string (nullable = true)
#  |    |    |    |    |-- git_commits_url: string (nullable = true)
#  |    |    |    |    |-- git_refs_url: string (nullable = true)
#  |    |    |    |    |-- git_tags_url: string (nullable = true)
#  |    |    |    |    |-- git_url: string (nullable = true)
#  |    |    |    |    |-- has_downloads: boolean (nullable = true)
#  |    |    |    |    |-- has_issues: boolean (nullable = true)
#  |    |    |    |    |-- has_pages: boolean (nullable = true)
#  |    |    |    |    |-- has_projects: boolean (nullable = true)
#  |    |    |    |    |-- has_wiki: boolean (nullable = true)
#  |    |    |    |    |-- homepage: string (nullable = true)
#  |    |    |    |    |-- hooks_url: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- issue_comment_url: string (nullable = true)
#  |    |    |    |    |-- issue_events_url: string (nullable = true)
#  |    |    |    |    |-- issues_url: string (nullable = true)
#  |    |    |    |    |-- keys_url: string (nullable = true)
#  |    |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |    |-- language: string (nullable = true)
#  |    |    |    |    |-- languages_url: string (nullable = true)
#  |    |    |    |    |-- license: struct (nullable = true)
#  |    |    |    |    |    |-- key: string (nullable = true)
#  |    |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- spdx_id: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- merges_url: string (nullable = true)
#  |    |    |    |    |-- milestones_url: string (nullable = true)
#  |    |    |    |    |-- mirror_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- notifications_url: string (nullable = true)
#  |    |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |    |-- open_issues_count: long (nullable = true)
#  |    |    |    |    |-- owner: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- private: boolean (nullable = true)
#  |    |    |    |    |-- pulls_url: string (nullable = true)
#  |    |    |    |    |-- pushed_at: string (nullable = true)
#  |    |    |    |    |-- releases_url: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- ssh_url: string (nullable = true)
#  |    |    |    |    |-- stargazers_count: long (nullable = true)
#  |    |    |    |    |-- stargazers_url: string (nullable = true)
#  |    |    |    |    |-- statuses_url: string (nullable = true)
#  |    |    |    |    |-- subscribers_url: string (nullable = true)
#  |    |    |    |    |-- subscription_url: string (nullable = true)
#  |    |    |    |    |-- svn_url: string (nullable = true)
#  |    |    |    |    |-- tags_url: string (nullable = true)
#  |    |    |    |    |-- teams_url: string (nullable = true)
#  |    |    |    |    |-- trees_url: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- watchers: long (nullable = true)
#  |    |    |    |    |-- watchers_count: long (nullable = true)
#  |    |    |    |-- sha: string (nullable = true)
#  |    |    |    |-- user: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- issue_url: string (nullable = true)
#  |    |    |-- labels: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- color: string (nullable = true)
#  |    |    |    |    |-- default: boolean (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- locked: boolean (nullable = true)
#  |    |    |-- maintainer_can_modify: boolean (nullable = true)
#  |    |    |-- merge_commit_sha: string (nullable = true)
#  |    |    |-- mergeable: boolean (nullable = true)
#  |    |    |-- mergeable_state: string (nullable = true)
#  |    |    |-- merged: boolean (nullable = true)
#  |    |    |-- merged_at: string (nullable = true)
#  |    |    |-- merged_by: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- milestone: struct (nullable = true)
#  |    |    |    |-- closed_at: string (nullable = true)
#  |    |    |    |-- closed_issues: long (nullable = true)
#  |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |-- creator: struct (nullable = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |-- description: string (nullable = true)
#  |    |    |    |-- due_on: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- labels_url: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- number: long (nullable = true)
#  |    |    |    |-- open_issues: long (nullable = true)
#  |    |    |    |-- state: string (nullable = true)
#  |    |    |    |-- title: string (nullable = true)
#  |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- number: long (nullable = true)
#  |    |    |-- patch_url: string (nullable = true)
#  |    |    |-- rebaseable: boolean (nullable = true)
#  |    |    |-- requested_reviewers: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- requested_teams: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- description: string (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- members_url: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- permission: string (nullable = true)
#  |    |    |    |    |-- privacy: string (nullable = true)
#  |    |    |    |    |-- repositories_url: string (nullable = true)
#  |    |    |    |    |-- slug: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- review_comment_url: string (nullable = true)
#  |    |    |-- review_comments: long (nullable = true)
#  |    |    |-- review_comments_url: string (nullable = true)
#  |    |    |-- state: string (nullable = true)
#  |    |    |-- statuses_url: string (nullable = true)
#  |    |    |-- title: string (nullable = true)
#  |    |    |-- updated_at: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- user: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |-- push_id: long (nullable = true)
#  |    |-- pusher_type: string (nullable = true)
#  |    |-- ref: string (nullable = true)
#  |    |-- ref_type: string (nullable = true)
#  |    |-- release: struct (nullable = true)
#  |    |    |-- assets: array (nullable = true)
#  |    |    |    |-- element: struct (containsNull = true)
#  |    |    |    |    |-- browser_download_url: string (nullable = true)
#  |    |    |    |    |-- content_type: string (nullable = true)
#  |    |    |    |    |-- created_at: string (nullable = true)
#  |    |    |    |    |-- download_count: long (nullable = true)
#  |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |-- label: string (nullable = true)
#  |    |    |    |    |-- name: string (nullable = true)
#  |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |-- size: long (nullable = true)
#  |    |    |    |    |-- state: string (nullable = true)
#  |    |    |    |    |-- updated_at: string (nullable = true)
#  |    |    |    |    |-- uploader: struct (nullable = true)
#  |    |    |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |    |    |-- id: long (nullable = true)
#  |    |    |    |    |    |-- login: string (nullable = true)
#  |    |    |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |    |    |-- type: string (nullable = true)
#  |    |    |    |    |    |-- url: string (nullable = true)
#  |    |    |    |    |-- url: string (nullable = true)
#  |    |    |-- assets_url: string (nullable = true)
#  |    |    |-- author: struct (nullable = true)
#  |    |    |    |-- avatar_url: string (nullable = true)
#  |    |    |    |-- events_url: string (nullable = true)
#  |    |    |    |-- followers_url: string (nullable = true)
#  |    |    |    |-- following_url: string (nullable = true)
#  |    |    |    |-- gists_url: string (nullable = true)
#  |    |    |    |-- gravatar_id: string (nullable = true)
#  |    |    |    |-- html_url: string (nullable = true)
#  |    |    |    |-- id: long (nullable = true)
#  |    |    |    |-- login: string (nullable = true)
#  |    |    |    |-- node_id: string (nullable = true)
#  |    |    |    |-- organizations_url: string (nullable = true)
#  |    |    |    |-- received_events_url: string (nullable = true)
#  |    |    |    |-- repos_url: string (nullable = true)
#  |    |    |    |-- site_admin: boolean (nullable = true)
#  |    |    |    |-- starred_url: string (nullable = true)
#  |    |    |    |-- subscriptions_url: string (nullable = true)
#  |    |    |    |-- type: string (nullable = true)
#  |    |    |    |-- url: string (nullable = true)
#  |    |    |-- body: string (nullable = true)
#  |    |    |-- created_at: string (nullable = true)
#  |    |    |-- draft: boolean (nullable = true)
#  |    |    |-- html_url: string (nullable = true)
#  |    |    |-- id: long (nullable = true)
#  |    |    |-- name: string (nullable = true)
#  |    |    |-- node_id: string (nullable = true)
#  |    |    |-- prerelease: boolean (nullable = true)
#  |    |    |-- published_at: string (nullable = true)
#  |    |    |-- tag_name: string (nullable = true)
#  |    |    |-- tarball_url: string (nullable = true)
#  |    |    |-- target_commitish: string (nullable = true)
#  |    |    |-- upload_url: string (nullable = true)
#  |    |    |-- url: string (nullable = true)
#  |    |    |-- zipball_url: string (nullable = true)
#  |    |-- size: long (nullable = true)
#  |-- public: boolean (nullable = true)
#  |-- repo: struct (nullable = true)
#  |    |-- id: long (nullable = true)
#  |    |-- name: string (nullable = true)
#  |    |-- url: string (nullable = true)
#  |-- type: string (nullable = true)
#  |-- year: integer (nullable = true)
#  |-- month: integer (nullable = true)
#  |-- day: integer (nullable = true)

# %%
df3.show()
# Out:
# +--------------------+--------------------+----------+--------------------+--------------------+------+--------------------+-----------------+----+-----+---+
# |               actor|          created_at|        id|                 org|             payload|public|                repo|             type|year|month|day|
# +--------------------+--------------------+----------+--------------------+--------------------+------+--------------------+-----------------+----+-----+---+
# |[https://avatars....|2018-07-24T16:00:00Z|8011174342|                null|[, 3d02b5ff979cea...|  true|[142025706, gameb...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174355|[https://avatars....|[created,, [, CON...|  true|[10941409, mesosp...|IssueCommentEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174362|                null|[, d8a47b6700dd02...|  true|[142157684, guiCa...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174365|                null|[, 325a4f61c4d8e8...|  true|[135834980, Rtcas...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174366|                null|[, 38a88744ae293c...|  true|[142036030, art12...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174368|[https://avatars....|[,,,, Angular (v2...|  true|[81668836, iotile...|      CreateEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174375|                null|[, 0de028a3f7946e...|  true|[86505380, davidp...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174376|                null|[,,,, Detta plugi...|  true|[142181923, PadsC...|      CreateEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174381|[https://avatars....|[started,,,,,,,,,...|  true|[64603480, EngFor...|       WatchEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174382|                null|[, 45742462b5549b...|  true|[142179091, seren...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174385|                null|[, 7ad58ffaed214d...|  true|[138676186, himob...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174386|                null|[, cd6a87f5694914...|  true|[142169764, shaly...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174393|[https://avatars....|[, f5d2399cd53202...|  true|[25623942, apache...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174397|                null|[, 6d550d9d6d3884...|  true|[135091897, Agata...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174406|                null|[,,,,,,,,, master...|  true|[139280926, benke...|      CreateEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174417|[https://avatars....|[closed,,,,,,,,,,...|  true|[8859285, wordpre...| PullRequestEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174420|                null|[, fa32ad6425f30d...|  true|[75402138, richar...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174422|[https://avatars....|[, 20f39530dc12e9...|  true|[126059498, Plaje...|        PushEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174423|                null|[published,,,,,,,...|  true|[142180375, JuAle...|     ReleaseEvent|2018|    7| 24|
# |[https://avatars....|2018-07-24T16:00:00Z|8011174428|[https://avatars....|[, d48bb8a452494f...|  true|[61103370, legato...|        PushEvent|2018|    7| 24|
# +--------------------+--------------------+----------+--------------------+--------------------+------+--------------------+-----------------+----+-----+---+
# only showing top 20 rows

# %%
spark.stop()
