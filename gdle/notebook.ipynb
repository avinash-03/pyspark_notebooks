# %%
import pandas as pd 

df = pd.read_csv("data2.csv")
df
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3194: DtypeWarning: Columns (8,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                0         1       2     3          4       5              6  \
# 0      255766932  20030611  200306  2003  2003.4411     USA  UNITED STATES
# 1      255766933  20030611  200306  2003  2003.4411     USA       AMERICAN
# 2      255766934  20030611  200306  2003  2003.4411     VNM        VIETNAM
# 3      255766935  20030611  200306  2003  2003.4411     VNM        VIETNAM
# 4      255766936  20120608  201206  2012  2012.4329     NaN            NaN
# ...          ...       ...     ...   ...        ...     ...            ...
# 23114  255790095  20130609  201306  2013  2013.4356  SDNGOV          SUDAN
# 23115  255790096  20130609  201306  2013  2013.4356     USA  UNITED STATES
# ...

# %%
# Out:
# 58
